# %%
import pandas as pd
import glob

# %%
for f in glob.glob("/proj/semafor/hackathons/hk3/cp4/*.json"):
    d = pd.read_json(f,orient="records")
    print(f)
# Out:
# /proj/semafor/hackathons/hk3/cp4/test_climate_EleutherAI-gpt-neo-1.3B_10.json
# /proj/semafor/hackathons/hk3/cp4/test_climate_EleutherAI-gpt-neo-1.3B_1.json
# /proj/semafor/hackathons/hk3/cp4/test_climate_EleutherAI-gpt-neo-1.3B_20.json
# /proj/semafor/hackathons/hk3/cp4/test_climate_EleutherAI-gpt-neo-1.3B_5.json
# /proj/semafor/hackathons/hk3/cp4/test_climate_gpt2_10.json
# /proj/semafor/hackathons/hk3/cp4/test_climate_gpt2_1.json
# /proj/semafor/hackathons/hk3/cp4/test_climate_gpt2_20.json
# /proj/semafor/hackathons/hk3/cp4/test_climate_gpt2_5.json
# /proj/semafor/hackathons/hk3/cp4/test_climate_gpt2-large_10.json
# /proj/semafor/hackathons/hk3/cp4/test_climate_gpt2-large_1.json
# /proj/semafor/hackathons/hk3/cp4/test_climate_gpt2-large_20.json
# /proj/semafor/hackathons/hk3/cp4/test_climate_gpt2-large_5.json
# /proj/semafor/hackathons/hk3/cp4/test_climate_gpt2-medium_10.json
# /proj/semafor/hackathons/hk3/cp4/test_climate_gpt2-medium_1.json
# ...
